# %%
import os
import pandas as pd
import numpy as np
import anndata as ann

import spatialdm as sdm
from spatialdm.datasets import dataset
import spatialdm.plottings as pl

import matplotlib.pyplot as plt
print("SpatailDM version: %s" %sdm.__version__)

from scipy.stats import spearmanr, pearsonr
import scanpy as sc
import liana as li
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="fd59be14-9d26-4e2c-a756-4935beb0886d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
adata = dataset.melanoma()
# Out:
# /home/dbdimitrov/anaconda3/envs/spatialdm/lib/python3.10/site-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
# /home/dbdimitrov/anaconda3/envs/spatialdm/lib/python3.10/site-packages/anndata/_core/anndata.py:183: ImplicitModificationWarning: Transforming to str index.

# %%
# NOTE: SpatialDM uses adata for global, and adata.raw for local -> make them identical
# I strongly disagree with permuting raw counts
# Also, there are some differences in how I define categories, and what they mask
# I mask negative corr and ambiguous corr, they only mask the latter
adata = adata.raw.to_adata()
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# adata = adata[:,['SPP1', 'CD44', 'IGF2', 'IGF1R']]
adata.raw = adata.copy()

# %%
sdm.weight_matrix(adata=adata, l=1.2, cutoff=0.1, single_cell=False) # weight_matrix by rbf kernel

# %%
# visualize range of interaction
import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))

# plt.scatter(adata.obsm['spatial'][:,0], adata.obsm['spatial'][:,1],
#             c=adata.obsp['weight'][50])

plt.scatter(adata.obsm['spatial'][:,0], 
            adata.obsm['spatial'][:,1],
            c=adata.obsp['weight'].A[50])

# %%
import time
start = time.time()
sdm.weight_matrix(adata, l=1.2, cutoff=0.2, single_cell=False) # weight_matrix by rbf kernel
sdm.extract_lr(adata, 'human', min_cell=3)

# %%
adata.obsp['nearest_neighbors'] = adata.obsp['weight']

# %%
sdm.spatialdm_global(adata, 100, specified_ind=None, method='both', nproc=1)     # global Moran selection
sdm.sig_pairs(adata, method='permutation', fdr=False, threshold=2)     # select significant pairs
sdm.spatialdm_local(adata, n_perm=100, method='both', specified_ind=None, nproc=1, scale_X=False)     # local spot selection
# Out:
# ...
# 100%|██████████| 100/100 [00:04<00:00, 21.98it/s]

# %%
adata.uns.keys()
# Out:
# odict_keys(['log1p', 'single_cell', 'mean', 'ligand', 'receptor', 'num_pairs', 'geneInter', 'global_I', 'global_stat', 'global_res', 'local_stat', 'local_z', 'local_z_p', 'local_perm_p'])

# %%
def _uns(adata, key):
    return adata.uns[key]

# %%
global_res = adata.uns['global_res']
global_res['morans_r'] = adata.uns['global_I'].flatten()

# %%
local_i = _uns(adata, 'local_stat')['local_I']
local_i_r = _uns(adata, 'local_stat')['local_I_R']
local_r = local_i + local_i_r
local_msk = ((local_i > 0) * (local_i_r > 0)).astype(int)
local_p = adata.uns['local_z_p']

# %%
spdata = ann.AnnData(X=local_r,
                     obs=adata.obs,
                     var=global_res,
                     obsm=adata.obsm,
                     layers={'pvals':local_p.T, 'cats':local_msk})

# %%
li.ut.spatial_neighbors(adata, bandwidth=1.2, cutoff=0.2, set_diag=True)

# %%
li.mt.lr_bivar(adata, 
               function_name="morans",
               inplace=True,
               use_raw=False,
               n_perms=0,
               expr_prop=0.1,
               verbose=True,
               mask_negatives=True,
               resource_name='cellchatdb',
               connectivity_key='weight',
               add_categories=True
               )
# Out:
# Using resource `cellchatdb`.
# Using `.X`!
# Converting to sparse csr matrix!
# /home/dbdimitrov/anaconda3/envs/spatialdm/lib/python3.10/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# ...

# %%
lrdata = adata.obsm['local_scores']

# %%
lrdata = lrdata[:,~lrdata.var.index.str.contains("_")].copy()

# %%
# replace ^ with _
lrdata.var.index = lrdata.var.index.str.replace('^', '_')

# %%
lrdata = lrdata[:, lrdata.var.index[lrdata.var.index.isin(spdata.var.index)]]

# %%
# sort by index
spdata = spdata[:,lrdata.var.index]

# %%
spearmanr(lrdata.var['morans_r'], spdata.var['morans_r'])
# Out:
# SignificanceResult(statistic=0.99999739111492, pvalue=0.0)

# %%
pearsonr(lrdata.var['morans_pvals'], spdata.var['perm_pval'])
# Out:
# PearsonRResult(statistic=0.980696638298478, pvalue=5.149643532101189e-94)

# %%
plt.scatter(lrdata.var['morans_r'], spdata.var['morans_r'], s=3)

# %%
msk = (spdata.layers['pvals'].flatten()!=1) & (lrdata.layers['pvals'].A.flatten()!=1)

# %%
pearsonr(lrdata.X.A.flatten()[msk], spdata.X.flatten()[msk])
# Out:
# PearsonRResult(statistic=0.9999999999993869, pvalue=0.0)

# %%
ax = plt.subplot(111)
ax.scatter(lrdata.X.A.flatten()[msk], spdata.X.flatten()[msk], s=1)

# %%
ax = plt.subplot(111)
ax.scatter(lrdata.layers['pvals'].A.flatten()[msk], spdata.layers['pvals'].flatten()[msk], s=1)

# %%
pearsonr(lrdata.layers['pvals'].A.flatten()[msk], spdata.layers['pvals'].flatten()[msk])
# Out:
# PearsonRResult(statistic=0.9999999999997039, pvalue=0.0)

# %%
plt.hist(lrdata.layers['pvals'].A.flatten()[msk]);

# %%
plt.hist(spdata.layers['pvals'].flatten()[msk])
# Out:
# (array([ 567.,  402.,  511.,  710., 1069., 1722., 1755.,  367.,   44.,
#            9.]),
#  array([3.58165574e-19, 8.12658506e-02, 1.62531701e-01, 2.43797552e-01,
#         3.25063402e-01, 4.06329253e-01, 4.87595103e-01, 5.68860954e-01,
#         6.50126805e-01, 7.31392655e-01, 8.12658506e-01]),
#  <BarContainer object of 10 artists>)

# %%
sc.pl.spatial(lrdata, color=['SPP1_CD44'], spot_size=1, layer='pvals', cmap='magma')
# Out:
# /home/dbdimitrov/anaconda3/envs/spatialdm/lib/python3.10/site-packages/anndata/_core/anndata.py:1292: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
# ... storing 'ligand' as categorical
# /home/dbdimitrov/anaconda3/envs/spatialdm/lib/python3.10/site-packages/anndata/_core/anndata.py:1292: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
# ... storing 'receptor' as categorical

# %%
sc.pl.spatial(lrdata, color=['SPP1_CD44'], spot_size=1, layer='cats', cmap='coolwarm')

# %%
sc.pl.spatial(spdata, color=['SPP1_CD44'], spot_size=1, layer='pvals', cmap='magma')
# Out:
# /home/dbdimitrov/anaconda3/envs/spatialdm/lib/python3.10/site-packages/anndata/_core/anndata.py:1292: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
# ... storing 'Ligand0' as categorical
# /home/dbdimitrov/anaconda3/envs/spatialdm/lib/python3.10/site-packages/anndata/_core/anndata.py:1292: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
# ... storing 'Receptor0' as categorical
